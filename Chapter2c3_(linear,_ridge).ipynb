# %% [markdown]
# <a href="https://colab.research.google.com/github/gabpoersch/oreillyPythonMLBook/blob/main/Chapter2c3_(linear%2C_ridge).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mglearn
import mglearn

mglearn.plots.plot_linear_regression_wave()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.4/581.4 kB 5.9 MB/s eta 0:00:00
# ...
# w[0]: 0.393906  b: -0.031804

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X, y = mglearn.datasets.make_wave(n_samples=60)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
lr = LinearRegression().fit(X_train, y_train)

print(lr.coef_)
print(lr.intercept_)
# Out:
# [0.39390555]
# -0.031804343026759746

# %%
print(lr.score(X_train, y_train))
print(lr.score(X_test, y_test))
# Out:
# 0.6700890315075756
# 0.65933685968637

# %%
X, y = mglearn.datasets.load_extended_boston()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
lr = LinearRegression().fit(X_train, y_train)

print(lr.score(X_train, y_train))
print(lr.score(X_test, y_test))
# Out:
# 0.9520519609032727
# 0.6074721959665794

# %%
from sklearn.linear_model import Ridge

ridge = Ridge().fit(X_train, y_train)
print(ridge.score(X_train, y_train))
print(ridge.score(X_test, y_test))
print('')

ridge10 = Ridge(alpha=10).fit(X_train, y_train)
print(ridge10.score(X_train, y_train))
print(ridge10.score(X_test, y_test))
print('')

ridge_decimal = Ridge(alpha=0.1).fit(X_train, y_train)
print(ridge_decimal.score(X_train, y_train))
print(ridge_decimal.score(X_test, y_test))
print('')
# Out:
# 0.8857966585170941
# 0.7527683481744752
#
# 0.7882787115369614
# 0.6359411489177309
#
# 0.9282273685001993
# 0.7722067936479827

# %%
import matplotlib.pyplot as plt

plt.plot(ridge.coef_, 's', label="Ridge alpha=1")
plt.plot(ridge10.coef_, '^', label="Ridge alpha=10")
plt.plot(ridge_decimal.coef_, 'v', label="Ridge alpha=0.1")
plt.plot(lr.coef_, 'o', label="LinearRegression")
plt.xlabel("Coefficient index")
plt.ylabel("Coefficient magnitude")
plt.hlines(0, 0, len(lr.coef_))
plt.ylim(-25, 25)
plt.legend()

# %%
mglearn.plots.plot_ridge_n_samples()
